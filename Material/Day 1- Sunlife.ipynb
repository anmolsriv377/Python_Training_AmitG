# %%
#This is a comment
#Python is case sensitive

#Addition
10+2
# Out:
# 12

# %%
#Multiplication
#*

#Division
# /

#int division
# //

10/3
# Out:
# 3.3333333333333335

# %%
10//3
# Out:
# 3

# %%
#Modulo operator
#remainder

10%3
# Out:
# 1

# %%
#Data Types 

#Numbers -- 
#Strings -- "" ''
#List -- []  mutable
#Tuples -- () immutable
#Dictionary -- {}
#Set -- {}
#Boolean --
#NoneType --

# %%
"Apple"
# Out:
# 'Apple'

# %%
x=print("Apple")

print(100)
# Out:
# Apple
# 100

# %%
x

# %%
type(x)
# Out:
# NoneType

# %%
type(True)

type(False)
# Out:
# bool

# %%
#Numbers
    #int
    #float
type(100)
# Out:
# int

# %%
type(100.5)
# Out:
# float

# %%
#variables
#variable name must start with an alphabet
#it can have a underscpre but not any other special character
x=100

# %%
x
# Out:
# 100

# %%
type(x)
# Out:
# int

# %%
x
# Out:
# 100

# %%
#Strings
#Text or character data

"Apple"
'Apple'
# Out:
# 'Apple'

# %%
stu_name="Sachin Tendulkar"

# %%
type(stu_name)
# Out:
# str

# %%
#Python -- indexing
stu_name[0]
# Out:
# 'S'

# %%
stu_name[1]
# Out:
# 'a'

# %%
#slicing
stu_name[0:3]
# Out:
# 'Sac'

# %%
stu_name[1:]
# Out:
# 'achin Tendulkar'

# %%
stu_name[:5]
# Out:
# 'Sachi'

# %%
stu_name[-1]
# Out:
# 'r'

# %%
stu_name[-2]
# Out:
# 'a'

# %%
stu_name[-3:]
# Out:
# 'kar'

# %%
stu_name[0:4:2]
# Out:
# 'Sc'

# %%
stu_name[::-1]
# Out:
# 'rakludneT nihcaS'

# %%
#Numbers
#Strings

#Methods -- inbuilt functions
stu_name.lower()
# Out:
# 'sachin tendulkar'

# %%
stu_name  #Strings is an immutable object
# Out:
# 'Sachin Tendulkar'

# %%
y=stu_name.upper()

# %%
id(stu_name)
# Out:
# 2457771028592

# %%
id(y)
# Out:
# 2457775810096

# %%
#delete a variable

del y

# %%
stu_name=stu_name.replace("S","C")

# %%
stu_name
# Out:
# 'Cachin Tendulkar'

# %%
id(stu_name)
# Out:
# 2457773366000

# %%
stu_name.find(" ")
# Out:
# 6

# %%
#Create a code to fetch the firstname and last name dynamically

stu_name="Virat Kohli"

# %%
split_index = stu_name.find(" ")
first_name=stu_name[0:split_index]
last_name=stu_name[split_index+1:]

# %%
print(first_name)
print(last_name)
# Out:
# Virat
# Kohli

# %%
stu_name.split(" ")
# Out:
# ['Virat', 'Kohli']

# %%
#list
#List is an object which is collection of multiple objects/elements
#List is a mutable object
#to create a list we use []

names=["Sam","John","Leo"]

# %%
names
# Out:
# ['Sam', 'John', 'Leo']

# %%
type(names)
# Out:
# list

# %%
L2=[100,200,300,"Sam", True, [2,3]]

# %%
#len
stu_name
# Out:
# 'Virat Kohli'

# %%
len(stu_name)
# Out:
# 11

# %%
len(L2)
# Out:
# 6

# %%
#indexing
type(names)
# Out:
# list

# %%
L2[-1][0]
# Out:
# 2

# %%
#15 mins break
#List methods

names
# Out:
# ['Sam', 'John', 'Leo']

# %%
names[0]="Sammy"

# %%
names
# Out:
# ['Sammy', 'John', 'Leo']

# %%
stu_name
# Out:
# 'Virat Kohli'

# %%
stu_name[0]="W"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 stu_name[0]="W"
#
# TypeError: 'str' object does not support item assignment

# %%
#append
#pop
#insert
#sort
#reverse


#append is used to add a new element

names.append("Joey")

# %%
names
# Out:
# ['Sammy', 'John', 'Leo', 'Joey']

# %%
names.pop()
# Out:
# 'Joey'

# %%
names
# Out:
# ['Sammy', 'John', 'Leo']

# %%
names.remove("John")

# %%
names
# Out:
# ['Sammy', 'Leo']

# %%
#insert
names.insert(1,"Maxx")

# %%
names
# Out:
# ['Sammy', 'Maxx', 'Leo']

# %%
#sort

names.sort()

# %%
names
# Out:
# ['Leo', 'Maxx', 'Sammy']

# %%
names.sort(reverse=True)

# %%
names
# Out:
# ['Sammy', 'Maxx', 'Leo']

# %%
#task

L=[1,2,3,[["Apple"]]]

#Extract A

# %%
L[3][0][0][0]
# Out:
# 'A'

# %%
L[-1][-1][-1][0]
# Out:
# 'A'

# %%
#Tuple
#it is alsoused to store multiple elements
#tuple is immutable
#()

names=("Sam","Joey","Leo")

# %%
names
# Out:
# ('Sam', 'Joey', 'Leo')

# %%
type(names)
# Out:
# tuple

# %%
names[0]
# Out:
# 'Sam'

# %%
names[0]="Sammy"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 names[0]="Sammy"
#
# TypeError: 'tuple' object does not support item assignment

# %%
t=("A","B",[1,2,3])

# %%
t[-1].append(4)

# %%
t
# Out:
# ('A', 'B', [1, 2, 3, 4])

# %%
#tuple
#index
#count

t.count("A")
# Out:
# 1

# %%
t.index("A")
# Out:
# 0

# %%
L=[1,2,3,(10,20), [30,40]]

# %%
#Dictionary

#it stores the data as a key value pair

# %%
d={"ID":[1,2,3,4], "Name":("A","B","C"), "Gender":"M"}

# %%
type(d)
# Out:
# dict

# %%
d.keys()
# Out:
# dict_keys(['ID', 'Name', 'Gender'])

# %%
d["ID"]
# Out:
# [1, 2, 3, 4]

# %%
d["Name"]
# Out:
# ('A', 'B', 'C')

# %%
d={"K1":[1,2,3,{"K2":["X"]}]}

# %%
d["K1"][3]["K2"][0]
# Out:
# 'X'

# %%
d["K1"][3]["K2"][0]
# Out:
# 'X'

# %%
d={"ID":[1,2,3,4], "Name":("A","B","C"), "Gender":"M"}

# %%
d["Subject"]=["Tableau","Python"]

# %%
d
# Out:
# {'ID': [1, 2, 3, 4],
#  'Name': ('A', 'B', 'C'),
#  'Gender': 'M',
#  'Subject': ['Tableau', 'Python']}

# %%
#Methods
#popitem : removes last key value pair
d.popitem()
# Out:
# ('Subject', ['Tableau', 'Python'])

# %%
d
# Out:
# {'ID': [1, 2, 3, 4], 'Name': ('A', 'B', 'C'), 'Gender': 'M'}

# %%
d.pop("Gender")
# Out:
# 'M'

# %%
d
# Out:
# {'ID': [1, 2, 3, 4], 'Name': ('A', 'B', 'C')}

# %%
#update

d.update({"Color":"Red"})

# %%
d
# Out:
# {'ID': [1, 2, 3, 4], 'Name': ('A', 'B', 'C'), 'Color': 'Red'}

# %%
d["Subject"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[119], line 1
# ----> 1 d["Subject"]
#
# KeyError: 'Subject'

# %%
#get

d.get("ID")
# Out:
# [1, 2, 3, 4]

# %%
d.get("Subject")

# %%
d.setdefault("ID")
# Out:
# [1, 2, 3, 4]

# %%
d.setdefault("Subject",0)
# Out:
# 0

# %%
d
# Out:
# {'ID': [1, 2, 3, 4], 'Name': ('A', 'B', 'C'), 'Color': 'Red', 'Subject': 0}

# %%
#Set
#this is used to store unique values

# %%
x={1,2,2,3,3}

# %%
x
# Out:
# {1, 2, 3}

# %%
#ordered and unordered
L=[100,50,200]

# %%
L
# Out:
# [100, 50, 200]

# %%
s={100,50,200}

# %%
s
# Out:
# {50, 100, 200}

# %%
s1={100,200,300}
s2={200,300,400}

# %%
s1.union(s2)
# Out:
# {100, 200, 300, 400}

# %%
s1.intersection(s2)
# Out:
# {200, 300}

# %%
s
# Out:
# {50, 100, 200}

# %%
s.pop()
# Out:
# 200

# %%
s1.difference(s2)
# Out:
# {100}

# %%
s
# Out:
# {50, 100}

# %%
s.discard(100)
#remove

# %%
s={100,200,300,400}

# %%
s[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[141], line 1
# ----> 1 s[0]
#
# TypeError: 'set' object is not subscriptable

# %%
s.pop()
# Out:
# 200

# %%
s
# Out:
# {100, 300, 400}

# %%
x=list(s).pop(1)

# %%
s
# Out:
# {100, 300, 400}

# %%
x
# Out:
# 400

# %%
s
# Out:
# {100, 300, 400}

# %%
l=list(s)

# %%
l.
# Out:
# [100, 400, 300]
