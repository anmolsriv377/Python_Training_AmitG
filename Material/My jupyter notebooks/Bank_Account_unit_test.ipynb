# %%
class BankAccount():
    def __init__(self, balance=0):
        self.balance=balance

    def deposit(self,amount):
        self.balance=+amount

    def withdraw(self,amount):
        if amount>self.balance:
            raise ValueError("Insufficient Funds")
        self.balance-=balance

# %%
import unittest

# %%
class Test_Bank_Account(unittest.TestCase):
    def test_initial_balance(self):
        account=BankAccount(100)
        self.assertEqual(account.balance, 100)

    def test_deposit(self):
        account=BankAccount(100)
        account.deposit(50)
        self.assertEqual(account.balance, 150)

    def tst_withdraw(self):
        account=BankAccount(100)
        account.withdraw(50)
        self.assertEqual(account.balance, 50)

    def test_withdraw_insufficient(self):
        account=BankAccount(100)
        with self.assertRaises(ValueError):
            account.withdraw(200)

# %%
unittest.main(argv=[''], verbosity=2, exit=False)
# Out:
# test_deposit (__main__.Test_Bank_Account.test_deposit) ... FAIL
# test_initial_balance (__main__.Test_Bank_Account.test_initial_balance) ... ok
# test_withdraw_insufficient (__main__.Test_Bank_Account.test_withdraw_insufficient) ... ok
#
# ======================================================================
# FAIL: test_deposit (__main__.Test_Bank_Account.test_deposit)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Administrator\AppData\Local\Temp\2\ipykernel_8848\1899372359.py", line 9, in test_deposit
#     self.assertEqual(account.balance, 150)
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 50 != 150
#
# ----------------------------------------------------------------------
# Ran 3 tests in 0.005s
#
# FAILED (failures=1)
