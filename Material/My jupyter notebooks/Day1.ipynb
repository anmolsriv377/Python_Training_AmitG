# %%
#This is a comment

# %%
#Python is case sensitive

# %%
#Addition 
10+2
# Out:
# 12

# %%
#Multiplication
10*2
#Division
10/2
#int division
# //
10//2
# Out:
# 5

# %%
#Modulo operator gives remainder
10%3
# Out:
# 1

# %%
# Data Types
# Numbers
# Strings
# List
# Tuple
# Dictionary
# Set
# Boolean
# None Type

# %%
# Numbers
# int
# float
type(100)
# Out:
# int

# %%
type(100.5)
# Out:
# float

# %%
# Variables
# variable name must start with an alphabet
# it can have underscore but not any special character
x = 100

# %%
x
# Out:
# 100

# %%
type(x)
# Out:
# int

# %%
# Strings
# Text or character data
"Apple"
# Out:
# 'Apple'

# %%
'Apple'
# Out:
# 'Apple'

# %%
stu_name = "Kushal Srivastava"

# %%
type(stu_name)
# Out:
# str

# %%
# Python indexing
stu_name[0]
# Out:
# 'K'

# %%
stu_name[1]
# Out:
# 'u'

# %%
# Slicing
stu_name[0:3]   # last will be exclusive i.e., not included
# Out:
# 'Kus'

# %%
stu_name[2:]
# Out:
# 'shal Srivastava'

# %%
stu_name[:4]  # 4th won't be included
# Out:
# 'Kush'

# %%
stu_name[-1]
# Out:
# 'a'

# %%
stu_name[-3:]
# Out:
# 'ava'

# %%
stu_name[0:4:2]  # step
# Out:
# 'Ks'

# %%
stu_name[::-1]  # Reverse
# Out:
# 'avatsavirS lahsuK'

# %%
# Since python is oop lang so every data structure is also and object
# String methods - inbuilt functions
stu_name.lower()
# Out:
# 'kushal srivastava'

# %%
stu_name.upper()
# Out:
# 'KUSHAL SRIVASTAVA'

# %%
stu_name
# Out:
# 'Kushal Srivastava'

# %%
y = stu_name
id(y)
# Out:
# 1539461278704

# %%
id(stu_name)
# Out:
# 1539461278704

# %%
stu_name.replace("K","S")
# Out:
# 'Sushal Srivastava'

# %%
del y

# %%
stu_name.find(" ")
# Out:
# 6

# %%
stu_name = stu_name.replace("K","S")

# %%
stu_name
# Out:
# 'Sushal Srivastava'

# %%
stu_name = "Kushal Srivastava"

# %%
stu_name
# Out:
# 'Kushal Srivastava'

# %%
stu_name.split(" ")
# Out:
# ['Kushal', 'Srivastava']

# %%
split_index = stu_name.find(" ")
first_name=stu_name[0:split_index]
last_name=stu_name[split_index+1:]

# %%
print(first_name)
print(last_name)
# Out:
# Kushal
# Srivastava

# %%
# List
# List is an object which is collection of multiple objects/elements
# List is a mutable object
# To create list we use []

names = ["Sam", "John", "Peter"]

# %%
type(names)
# Out:
# list

# %%
names
# Out:
# ['Sam', 'John', 'Peter']

# %%
L2 = [100, 200, 300, "Kushal", True, [2,3]]

# %%
len(L2)
# Out:
# 6

# %%
L2[-1]
# Out:
# [2, 3]

# %%
L2[-1][0]
# Out:
# 2

# %%
# append
# pop
# insert
# sort
# reverse

# append is used to add a new element

names.append("Joey")

# %%
names
# Out:
# ['Sam', 'John', 'Peter', 'Joey']

# %%
names.pop()  # By default last element is removed
# Out:
# 'Joey'

# %%
names
# Out:
# ['Sam', 'John', 'Peter']

# %%
names.pop(1)
# Out:
# 'John'

# %%
names
# Out:
# ['Sam', 'Peter']

# %%
names.remove("Sam")

# %%
names
# Out:
# ['Peter']

# %%
names.append("Simon")

# %%
names
# Out:
# ['Peter', 'Simon']

# %%
names.insert(1, "Maxx")

# %%
names
# Out:
# ['Peter', 'Maxx', 'Simon']

# %%
# sort works when all elements are of same type
names.sort()

# %%
names
# Out:
# ['Maxx', 'Peter', 'Simon']

# %%
names.sort(reverse=True)
names
# Out:
# ['Simon', 'Peter', 'Maxx']

# %%
# Task
L = [1,2,3,4,[["Apple"]]]
# Extract A
L[4]
L[-1][-1][-1][0]
# Out:
# 'A'

# %%
# Tuple
# it is also used to store multiple elements 
# difference between list and tuple is tuple is immutable 
# and be use round brackets () and not [] like in list

names = ("Kushal", "Anmol", "Amay")

# %%
names
# Out:
# ('Kushal', 'Anmol', 'Amay')

# %%
type(names)
# Out:
# tuple

# %%
names[0]
# Out:
# 'Kushal'

# %%
names[0] = "Anmol"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 names[0] = "Anmol"
#
# TypeError: 'tuple' object does not support item assignment

# %%
t = ("A", "B", [1,2,3])

# %%
# tuple is immutable but list is mutable so if listinside tuple then we can change it
t[-1].append(4)

# %%
t
# Out:
# ('A', 'B', [1, 2, 3, 4])

# %%
# index and count in tuple
t.count("A")
# Out:
# 1

# %%
t.index("A")
# Out:
# 0

# %%
L = [1,2,3,4,(10,20),[30,40]]
L
# Out:
# [1, 2, 3, 4, (10, 20), [30, 40]]

# %%
# Dictionary
# It stores the data as key value pairs
# We use curly braces {}
# Dictionary does not have indexing
d = {"ID":[1,2,3,4], "Name":("A","B","C"), "Gender":"M"}

# %%
type(d)
# Out:
# dict

# %%
d.keys()
# Out:
# dict_keys(['ID', 'Name', 'Gender'])

# %%
d["ID"]
# Out:
# [1, 2, 3, 4]

# %%
# Dictionary is non iterable
# Task
d={"K1":[1,2,3,{"K2":["X"]}]}
d["K1"][3]["K2"][0]
# Out:
# 'X'

# %%
x={"ID":[1,2,3,4], "Name":("A","B","C"), "Gender":"M"}

# %%
d["Subject"]=
# Out:
#   Cell In[107], line 1
#     d["Subject"]=
#                  ^
# SyntaxError: invalid syntax

# %%
# Methods
# popitem : removes by default the last key and with pop we have to define the key to remove
x
# Out:
# {'ID': [1, 2, 3, 4], 'Name': ('A', 'B', 'C'), 'Gender': 'M'}

# %%
x.popitem()
# Out:
# ('Gender', 'M')

# %%
x.pop("Name")
# Out:
# ('A', 'B', 'C')

# %%
x
# Out:
# {'ID': [1, 2, 3, 4]}

# %%
# update
x.update({"Color":"Red"})

# %%
x
# Out:
# {'ID': [1, 2, 3, 4], 'Color': 'Red'}

# %%
x["Subject"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[117], line 1
# ----> 1 x["Subject"]
#
# KeyError: 'Subject'

# %%
# get
x.get("ID")
# Out:
# [1, 2, 3, 4]

# %%
x.get("Subject")  # Will not give any error

# %%
# set default
x.setdefault("ID")
# Out:
# [1, 2, 3, 4]

# %%
x.setdefault("Subject",9)   # will add this as a new key value pair
# Out:
# 9

# %%
x
# Out:
# {'ID': [1, 2, 3, 4], 'Color': 'Red', 'Subject': 9}

# %%
# Set
# this is used to store only unique values
# and saves the values in a sorted order
# this also used curly braces {} and to differentiate set does not have key value pairs
x = {1,2,3,3,4,2}

# %%
x
# Out:
# {1, 2, 3, 4}

# %%
# ordered and unordered
# In List
L = [100, 50, 70, 200]
L
# Out:
# [100, 50, 70, 200]

# %%
# But in set
s = {100, 50, 200}
s
# Out:
# {50, 100, 200}

# %%
s1 = {100, 200, 300}
s2 = {200, 300, 400}

# %%
s1.union(s2)
# Out:
# {100, 200, 300, 400}

# %%
s1.intersection(s2)
# Out:
# {200, 300}

# %%
s.pop()
# Out:
# 200

# %%
s1.difference(s2)    # present in s1 but not in s2
# Out:
# {100}

# %%
s
# Out:
# {50, 100}

# %%
s.discard(100)

# %%
s
# Out:
# {50}

# %%
# There is no indexing in set and it converts into a unique set of values
s = {100, 200, 300, 400}
s[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[138], line 3
#       1 # There is no indexing in set and it converts into a unique set of values
#       2 s = {100, 200, 300, 400}
# ----> 3 s[0]
#
# TypeError: 'set' object is not subscriptable

# %%
# discard and remove are same

# %%
# We can convert set into list also
list(s).pop(1)
# Out:
# 100

# %%
"Apple"
# Out:
# 'Apple'

# %%
# None Type
x = print("Apple")
# Out:
# Apple

# %%
type(x)
# Out:
# NoneType
