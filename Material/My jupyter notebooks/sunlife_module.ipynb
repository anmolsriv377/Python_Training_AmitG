# %%
def check_even(num):
    if num%2==0:
        return "Even"
    else:
        return "Odd"

# %%
def greetings(name):
    return "Welcome "+ name

# %%
def fact(num):
    fact=1
    for i in range(1,num+1):
        fact = fact*i
    return fact
