# %%
X = stu_name.split(" ")
FirstName = X[0]
LastName = X[1]
FirstName
LastName


Amod

split_index = stu_name.find(" ")
first_name=stu_name[0:split_index]
last_name=stu_name[split_index+1:]




L=[1,2,3,[["Apple"]]]
Priya
L[3][0][0][0]

Amod
L[-1][0][0][0]


d={"K1":[1,2,3,{"K2":["X"]}]}

#Extract X
Priya
d["K1"][3]["K2"][0]

Sonu
d["K1"][-1]["K2"][0]


SQL Session : https://drive.google.com/drive/u/1/folders/1zRMtz5N7o9LmRZobPy0UUIE63s9_1JeC


https://drive.google.com/drive/u/1/folders/1JbnTVpNawI1zcUH7bjY_fjcubbqF08zj

Priya

num = int(input("Enter the numner:"))
if (num%5==0) and (num%7==0):
    print("HiBye")
elif num%7==0:
    print("Bye")
elif num%5==0:
    print("Hi")
else:
    print("NA")
    

Amod
num=int(input("Enter the number : "))
if num%5==0 and num%7==0:
    print("HiBye")
elif num%7==0:
    Print("Bye")
elif num%5==0:
    print("Hi")
else:
    print("NA"



Muskan
num = int(input("Enter the number : "))

if num % 5 == 0 and num%7 == 0:
 print("HiBye")
elif num%5 == 0:
 print("Hey")
elif num%7 == 0:
 print("Bye")
else:
 print("NA")
        


L=[101,202,50,81,90]

Vishal
L=[101,202,50,81,90]
for i in L:
    if i % 2 == 0 :
        print (i)

Priya
L=[101,202,50,81,90]
print("Even Numbers are:")
for i in L:
    if(i%2==0):
        print(i)

#List
L=[101,202,50,81,90]
print("Even Numbers are:")
x = []
for i in L:
    if(i%2==0):
        x.append(i) 
print(x)

Jyoti
L=[101,202,50,81,90]

for i in L:
    if i%2 == 0:
        print(i)

Amod
L=[101,202,50,81,90]
for i in L:
    if i%2 == 0:
        print(i)

-------------------------------
L=[101,202,50,81,90]
out=[]
for i in L:
    if i%2 == 0:
        out.append(i)

print("List of even numbers : ", out)

-----------------------------------
Sonu
L=[101,202,50,81,90]
evenlist=[]
for i in L:
    if i%2==0:
        evenlist.append(i)
print(evenlist)
print(G)


#Factorial
Priya
num  = int(input("Enter a number:"))
fact=1
for i in range(1, num+1):
    fact = fact*i
print(fact)

Amod
#Factorilal
num=int(input("Enter the number for which you want to calculate factorial"))
result=1
for i in range(1, num):
    result=num*result
    num=num-1


print("Factorial is :", result)





Amod
name=["Sam", "John", "Leo"]
wts=[33, 22, 31]

for i in range(0, len(name)):
    pkts=wts[i]//5 + (wts[i]%5) 
    print(name[i], " got ", pkts, " packets.")

Priya
num = int(input("enter the number"))
while num<0:
    num = int(input("enter the number again, Negative not allowed"))
else:
    fact=1
    for i in range(1, num+1):
        fact = fact*i
print(fact)


Amod


def jamesBond(L):
    L1=[0,0,7,'X']
    for num in L:
        i=0;
        if L[num] == L1[i]:
            L1.pop(i)
    if len(L1) == 1:
        return True
    else:
        return False



Amod




def start_game():
    print("Welcome to the game")
    name=input("Please enter your name")
    print("Hello", name, "Your mission is to find a hidden treasure")
    print("Where do you want to go")
    print("1. Forest")
    print("2. Cave")

    choice=int(input("Enter your choice as 1 or 2"))
    if choice ==1:
        forest()
    elif choice==2:
        cave()
    else:
        print("Invalid Choice")
        start_game()
        
        

def forest():
    print("Welcome to the forest")
    print("You are in a forest and you see an animal")
    print("1. Climb a tree")
    print("2. Run")
    choice=int(input("Enter your choice as 1 or 2"))
    
    if choice==1:
        print("You won the game")
    else:
        print("You Lost")

def cave():
    print("Welcome to the cave")
    print("You are in a cave and its dark")
    print("1. Light a torch")
    print("2. Run")
    choice=int(input("Enter your choice as 1 or 2"))
    
    if choice==1:
        print("You won the game")
    else:
        print("You Lost")





lambda --

map
filter


Exception handling
file handling

qty = lambda text: int(text.split()[-1])


Amod
fn1 = lambda s: int (s.split()[-1])



fn1 = lambda s: int (s.split()[-1])


Amod
L=[10,20,30]
sq=lambda x: x*x
list(map(sq, L))

qty=lambda s:int(s.split(" ")[-1])



data=["1 Pen 20","2 Pen 100","3 Pen 50" ]

Anshul
sum(map(lambda x:int(x.split()[-1]),data))

totalQty = 0
for i in data:
    words = i.split()
    quantity = int(words[-1])
    totalQty += quantity
print("Total Quantity:", totalQty)




data=["1 Pen 20","2 Pencil 30","3 Pen 5","4 Pencil 50"]
# Out:
#   Cell In[32], line 35
#     SQL Session : https://drive.google.com/drive/u/1/folders/1zRMtz5N7o9LmRZobPy0UUIE63s9_1JeC
#                                                              ^
# SyntaxError: invalid decimal literal

# %%
data=["1 Pen 20","2 Pencil 30","3 Pen 5","4 Pencil 50"]

penItem=filter(lambda i: i.split()[1]=="Pen",data)
# penItem=list(filter(lambda i: i.split()[1]=="Pen",data))
# print(penItem)
totalQty = sum(map(lambda i: int(i.split()[-1]), penItem))
print(totalQty)
# Out:
# ['1 Pen 20', '3 Pen 5']
# 25

# %%
data2=["1 2-Feb 30", "2 3-Feb 50", "3 5-Mar 70"]

sum(map(lambda i: int(i.split()[-1]), filter(lambda y: "Feb" in y, data2)))
# Out:
# 80

# %%
# File Handling
# read
# write
# append
# read mode

file = open(r"C:\Users\Administrator\Downloads\sample file.txt", "r")

# %%
content=file.read()
print(content)
# Out:
# This is a file
# New file

# %%
content
# Out:
# 'This is a file\nNew file'

# %%
file.close()

# %%
content
# Out:
# 'This is a file\nNew file'

# %%
file = open(r"C:\Users\Administrator\Downloads\sample file.txt", "r")

# %%
content = file.readlines()

# %%
content
# Out:
# ['This is a file\n', 'New file']

# %%
file.close()

# %%
file = open(r"C:\Users\Administrator\Downloads\sample file1.txt", "w")
#  always creates new filr or overwrites existing
file.write("This ia a new file \n This is to understand file handling")
# Out:
# 56

# %%
file.close()

# %%
# x mode throws error if file already exists

# %%
# append mode creates new or adds data and not overwrites to existing file
file = open(r"C:\Users\Administrator\Downloads\sample file1.txt", "a")
file.write("\n appending data")
# Out:
# 16

# %%
file.close()

# %%
# csv files

#Load the data
#Calculate the total balance
#Calcute the total balance of England Region
#Calcukate the average Age

file = open(r"C:\Users\Administrator\Downloads\P1-UK-Bank-Customers (1) (8).csv","r")

# %%
content=file.read()
file.close()

# %%
# Exception Handling
