# %% [markdown]
# # Python Practice Workbook
# Fill in the code cells below to solve each question.

# %% [markdown]
# ## 1. Sales Analysis

# %%
sales=[2500,1800,3200,2900,4100,1700,3600]
# Write your solution here

# %% [markdown]
# ## 2. Employee Names

# %%
employees=["John","Alice","Bob","Alice","David","John","Emma"]
# Write your solution here

# %% [markdown]
# ## 3. Product Inventory

# %%
products=["Laptop","Mouse","Keyboard","Monitor","Mouse","Laptop"]
# Write your solution here

# %% [markdown]
# ## 4. Student Marks

# %%
marks=[56,89,45,78,92,67,81,39]
# Write your solution here

# %% [markdown]
# ## 5. Shopping Cart

# %%
cart=["Milk","Bread","Eggs","Butter"]
# Write your solution here

# %% [markdown]
# ## 6. Employee Details

# %%
employee=("E101","Rahul","Finance",65000)
# Write your solution here

# %% [markdown]
# ## 7. Monthly Temperatures

# %%
temps=(32,35,31,30,36,37,34)
# Write your solution here

# %% [markdown]
# ## 8. Exam Scores

# %%
scores=(85,72,90,67,88,95,76)
# Write your solution here

# %% [markdown]
# ## 9. Employee Salary Lookup

# %%
employees={"John":55000,"Alice":62000,"Bob":58000,"Emma":70000}
# Write your solution here

# %% [markdown]
# ## 10. Student Grades

# %%
grades={"Rahul":78,"Sneha":92,"Amit":67,"Priya":88}
# Write your solution here

# %% [markdown]
# ## 11. Product Prices

# %%
prices={"Laptop":65000,"Mouse":800,"Keyboard":1200,"Monitor":15000}
# Write your solution here

# %% [markdown]
# ## 12. Word Frequency Counter

# %%
text="python is easy and python is powerful"
# Write your solution here

# %% [markdown]
# ## 13. Customer Purchases

# %%
store1={"Laptop","Mouse","Keyboard","Monitor"}
store2={"Keyboard","Monitor","Printer","Scanner"}
# Write your solution here

# %% [markdown]
# ## 14. Student Enrollment

# %%
python_students={"Amit","Rahul","Priya","Sneha"}
sql_students={"Rahul","Priya","Karan","Neha"}
# Write your solution here

# %% [markdown]
# ## 15. Unique Email Domains

# %%
emails=["john@gmail.com","alice@yahoo.com","bob@gmail.com","emma@outlook.com","rahul@yahoo.com","priya@gmail.com"]
# Write your solution here
